# %% [markdown]
# # Analysis of an experiment demo

# %%
from midastouch.analyzer import Analyzer
import os

# %% [markdown]
# Choose an experiment that we want to analyze and load the data:

# %%
dir = os.getcwd()
a = Analyzer(datadir=dir+'/experiment_2021-12-17_22_13_51.csv',
            paramdir=dir+'/params_2021-12-17_22_13_51.py')
a.load_data()

# %% [markdown]
# The parameters of the algorihtm can be retrieved by the following command:

# %%
a.get_parameters()
# Out:
# {'before_after_weights': {'before': 4, 'same time': 1, 'after': 0.1},
#  'decay': 'exponential',
#  'max_dist': 3,
#  'n_investments': 30,
#  'cvg_thresh': 0.001}

# %% [markdown]
# The following function gives back the top ranked investors. The rank is supposed to represent how 'related' they are to brand-name investors (which have a score of 1 by definition).

# %%
a.investor_ranking(top_n=100)
# Out:
#                       investor_name     score  distance  investments  \
# 0                                GV  1.000000         0          914
# 30                            Accel  1.000000         0         1717
# 99                         Greylock  1.000000         0          774
# 113                        Redpoint  1.000000         0          684
# 130                       Benchmark  1.000000         0          635
# 228                     Lux Capital  1.000000         0          360
# 341                   Founders Fund  1.000000         0          726
# 348                   Intel Capital  1.000000         0         1488
# 357                   Mayfield Fund  1.000000         0          607
# 2069                    Paul Graham  1.000000         0           31
# 383                   True Ventures  1.000000         0          589
# 430                  Menlo Ventures  1.000000         0          687
# 1872                      Eric Ries  1.000000         0           51
# 1682                           DCVC  1.000000         0          434
# 508                 Khosla Ventures  1.000000         0          973
# 510                 Kleiner Perkins  1.000000         0         1310
# 528                 Sequoia Capital  1.000000         0         1601
# 549                Battery Ventures  1.000000         0          778
# 564                Felicis Ventures  1.000000         0          527
# 570                General Catalyst  1.000000         0          994
# 1079                      Floodgate  1.000000         0          340
# 603                Trinity Ventures  1.000000         0          463
# 1059                            CRV  1.000000         0          594
# 996     Lightspeed Venture Partners  1.000000         0         1053
# 951       New Enterprise Associates  1.000000         0         1985
# 656               Lowercase Capital  1.000000         0          188
# 830           Union Square Ventures  1.000000         0          363
# 702              Foundation Capital  1.000000         0          648
# 740             First Round Capital  1.000000         0          821
# 93                         Elad Gil  1.000000         0          116
# 729             Andreessen Horowitz  1.000000         0         1110
# 3924             ASU Venture Devils  0.741868         1          131
# 2599                Marc Andreessen  0.605932         1           36
# 264                    DAG Ventures  0.569300         1          253
# 3812                 eSeed Ventures  0.552697         1           38
# 271                    Fuse Capital  0.543294         1           53
# 1997                    Aaron Levie  0.528116         1           44
# 280                    Keith Rabois  0.524342         1           58
# 2334                  Ronald Conway  0.519902         1           98
# 2036                    Jeff Weiner  0.518429         1           41
# 3011             Rose Tech Ventures  0.518398         1           42
# 988     Crosspoint Venture Partners  0.517971         1           87
# 669               Pinnacle Ventures  0.513399         1           77
# 611               Advanced Equities  0.509370         1           45
# 3191           Pilot House Ventures  0.508811         1           54
# 2476                 Reflex Capital  0.503939         1           43
# 370                   Shlomo Kramer  0.503470         1           50
# 2271                  Georges Harik  0.500004         1           43
# 666               Northgate Capital  0.495187         1          112
# 685               Valhalla Partners  0.493480         1           90
# 431                  Mitchell Kapor  0.491774         1           56
# 347                   Icon Ventures  0.488714         1          185
# 2013                    Chris Sacca  0.487941         1           39
# 2548                Charlie Cheever  0.486086         1           41
# 3087            MentorTech Ventures  0.482739         1           43
# 45                           Oracle  0.481303         1           41
# 943       Inventus Capital Partners  0.480768         1           54
# 801            Wing Venture Capital  0.480729         1          122
# 1112                  Baker Capital  0.480168         1           41
# 2729               Joshua Schachter  0.479126         1           68
# 1012  Lehman Brothers Holdings Inc.  0.478450         1          107
# 3701                   Tata Capital  0.476810         1           31
# 3512    Summerhill Venture Partners  0.476795         1           31
# 417                  Focus Ventures  0.476065         1          136
# 638               Fidelity Ventures  0.475524         1          111
# 2190                   Reid Hoffman  0.473850         1           73
# 525                 Raymond Tonsing  0.472517         1           52
# 3803                   The Morpheus  0.469618         1           43
# 860          Stata Venture Partners  0.467130         1           55
# 3377        Time Warner Investments  0.464312         1           94
# 3730         Serruya Private Equity  0.463487         1           31
# 3381        Webb Investment Network  0.462901         1          142
# 800            VentureTech Alliance  0.459938         1           45
# 930        Tallwood Venture Capital  0.459306         1           57
# 721              Vesbridge Partners  0.458360         1           31
# 2731               Juniper Networks  0.457170         1           46
# 650               J.H. Whitney & Co  0.455734         1           44
# 942       Integral Capital Partners  0.455165         1          100
# 2074                    S28 Capital  0.453881         1           68
# 922        Madrone Capital Partners  0.453110         1           37
# 224                     K9 Ventures  0.452229         1           69
# 2299                  Merus Capital  0.451090         1           69
# 1015  Worldview Technology Partners  0.450515         1          135
# 401                  Ashton Kutcher  0.449184         1           61
# 1973                     Start Fund  0.448137         1           65
# 1156              Ignition Partners  0.445049         1          312
# 256                    AllegisCyber  0.444861         1          120
# 2901              Sherpalo Ventures  0.443847         1           69
# 967      Globespan Capital Partners  0.443613         1          202
# 1147               Keytone Ventures  0.441107         1           36
# 2002                    Ariel Poler  0.439868         1           41
# 1091                    ComVentures  0.438419         1          129
# 2023                    Formation 8  0.437978         1          154
# 3796                    StartupYard  0.437817         1           78
# 3059            Caffeinated Capital  0.437125         1          107
# 2533                Baroda Ventures  0.435978         1           57
# 3473     Coolidge Corner Investment  0.435614         1           49
# 1929                     Dave Morin  0.434985         1           61
# 2859              Jeremy Stoppelman  0.434336         1           42
# 512                 Matrix Partners  0.433488         1          605
#
#                                               neighbors
# 0     {'NFX': 5.4, 'REV': 26.6, 'Google': 29.7000000...
# 30    {'14W': 50.40000000000001, 'H14': 23.4, 'TCV':...
# 99    {'RUSNANO': 28.700000000000003, 'Gimv': 41.900...
# 113   {'ESO Fund': 1.0999999999999999, 'Greylock': 8...
# 130   {'Sapphire': 22.1, 'DAG Ventures': 473.3000000...
# 228   {'SV Angel': 57.30000000000002, 'George Burke'...
# 341   {'GIC': 19.299999999999997, 'SV Angel': 312.40...
# 348   {'TPG Growth': 26.1, 'Sprout Group': 54.900000...
# 357   {'Fuse Capital': 36.4, 'Accel': 109, 'Sapphire...
# 2069  {'JAM Fund': 0.1, 'Xavier Niel': 1.1, '4DX Ven...
# 383   {'REV': 14.699999999999998, 'Intel Capital': 4...
# 430   {'TCV': 13.299999999999999, 'Cross Creek': 4.8...
# 1872  {'DCVC': 6, 'Pear VC': 17.2, 'HAX': 8.2, 'SOSV...
# 1682  {'GIC': 8.799999999999999, 'Battery Ventures':...
# 508   {'G Squared': 24.700000000000003, 'Bill Gates'...
# 510   {'TCV': 37.400000000000006, 'Accel': 134, 'Foc...
# 528   {'Alumni Ventures': 16.900000000000006, 'Tenay...
# 549   {'ESO Fund': 1.7000000000000004, 'PremjiInvest...
# 564   {'Sapphire': 36.30000000000002, 'Skip Capital'...
# 570   {'Accel': 198, 'WndrCo': 11.2, 'Crowdcube': 49...
# 1079  {'Cherry Tree Investments': 37.00000000000001,...
# 603   {'Lakestar': 13.499999999999995, 'Matrix Partn...
# 1059  {'Matrix Partners': 290.2, 'Tudor Growth Equit...
# 996   {'GIC': 21.700000000000003, 'Founders Fund': 8...
# 951   {'J.H. Whitney & Co': 122.39999999999992, 'DFJ...
# 656   {'Accel': 29, 'EquityZen': 0.1, 'Sands Capital...
# 830   {'SV Angel': 291.7000000000003, 'Lux Capital':...
# 702   {'DHVC': 56.90000000000001, 'ZhenFund': 5, 'GG...
# 740   {'GV': 149, 'TPG Biotech': 24.200000000000003,...
# 93    {'Group 11': 41.1, 'Base Partners': 5.39999999...
# 729   {'Accel': 140, 'Goldman Sachs': 43.50000000000...
# 3924  {'SFC Capital': 1, 'Jared Leto': 1, 'Dylan Fie...
# 2599  {'Greylock': 24.2, 'Floodgate': 8, 'Reid Hoffm...
# 264   {'Sapphire': 10, 'Benchmark': 473.300000000001...
# 3812  {'Collaborative Fund': 2, 'Bold Capital Partne...
# 271   {'Mayfield Fund': 36.4, 'Foundation Capital': ...
# 1997  {'Jared Leto': 6, 'Eric Wu': 1, 'Elad Gil': 17...
# 280   {'DAG Ventures': 3, 'Sequoia Capital': 46.2000...
# 2334  {'Telstra Ventures': 2, 'Akkadian Ventures': 2...
# 2036  {'Dylan Field': 5, 'Kevin Hartz': 2, 'Lachy Gr...
# 3011  {'New York Angels': 36, 'Felicis Ventures': 16...
# 988   {'Foundation Capital': 61.70000000000001, 'Cat...
# 669   {'RUSNANO': 4, 'Greylock': 88.99999999999999, ...
# 611   {'Credit Suisse': 2, 'Manhattan Venture Partne...
# 3191  {'Sevin Rosen Funds': 9, 'Matrix Partners': 49...
# 2476  {'Credo Ventures': 17, 'Index Ventures': 16, '...
# 370   {'Coatue': 18, 'Greylock': 58.20000000000001, ...
# 2271  {'EASME - EU Executive Agency for SMEs': 1, 'A...
# 666   {'Tenaya Capital': 25, 'Sequoia Capital': 229....
# 685   {'Menlo Ventures': 33.7, 'HarbourVest Partners...
# 431   {'HOF Capital': 1, 'GP Bullhound': 1, 'OMERS V...
# 347   {'ESO Fund': 1, 'PremjiInvest': 1, 'RUSNANO': ...
# 2013  {'Biz Stone': 1, 'Max Levchin': 4, 'Anthos Cap...
# 2548  {'Y Combinator': 21, 'Arena Ventures': 2, 'Kev...
# 3087  {'Accel': 21.700000000000003, 'Rho Ventures': ...
# 45    {'Novartis': 1, 'Asset Management Ventures (AM...
# 943   {'Menlo Ventures': 126.79999999999993, 'IA Cap...
# 801   {'Redpoint': 43.600000000000016, 'Altimeter Ca...
# 1112  {'ComVentures': 15, 'New Enterprise Associates...
# 2729  {'DFJ Growth': 5, 'Lone Pine Capital': 2, 'Wel...
# 1012  {'Foundation Capital': 16.5, 'Crosspoint Ventu...
# 3701  {'Accel': 26.4, 'RA Capital Management': 6, 'C...
# 3512  {'Temasek Holdings': 9, 'Union Square Ventures...
# 417   {'Benchmark': 58.40000000000001, 'EPIC Venture...
# 638   {'Atlas Venture': 23, 'CARB-X': 1, 'CMEA Capit...
# 2190  {'SV Angel': 15, 'Pathfinder': 1, 'David Sacks...
# 525   {'GV': 33.7, 'NFX': 3, 'ZhenFund': 1, 'Polycha...
# 3803  {'Tracxn labs': 1, 'India Quotient': 2, 'Khosl...
# 860   {'General Catalyst': 73.49999999999999, 'Verte...
# 3377  {'GV': 11.899999999999999, '500 Startups': 10,...
# 3730  {'Evolution VC Partners': 1, 'Tiger Global Man...
# 3381  {'Partech': 2, 'Wavemaker Partners': 4, 'Morad...
# 800   {'RUSNANO': 4, 'Greylock': 40.20000000000001, ...
# 930   {'BlueRun Ventures': 12, 'Intel Capital': 34.9...
# 721   {'Innovacom': 5, 'JK&B Capital': 3, 'Intel Cap...
# 2731  {'AT&T': 1, 'Microsoft': 2, 'NBCUniversal': 1,...
# 650   {'New Enterprise Associates': 122.399999999999...
# 942   {'TPG Growth': 5, 'Sprout Group': 11, 'Intel C...
# 2074  {'Lakestar': 2, 'Greylock': 34.6, 'LeFrak': 4,...
# 922   {'Jackson Square Ventures': 20, 'Dragoneer Inv...
# 224   {'DTCP': 7, 'Sapphire': 21, 'Telstra Ventures'...
# 2299  {'Compound': 4, '500 Startups': 15, 'Ulu Ventu...
# 1015  {'Crosslink Capital': 26, 'Artis Ventures (AV)...
# 401   {'GIC': 4, 'Founders Fund': 19.799999999999997...
# 1973  {'SV Angel': 56, 'Garry Tan': 13, 'Lee Linden'...
# 1156  {'Innovacom': 15, 'Samsung Electronics': 5, 'A...
# 256   {'Shasta Ventures': 10, 'Granite Ventures': 18...
# 2901  {'Baseline Ventures': 3, 'SV Angel': 22, 'E-Me...
# 967   {'Menlo Ventures': 165.59999999999985, 'IA Cap...
# 1147  {'Menlo Ventures': 4.199999999999999, 'Sierra ...
# 2002  {'Eric Wu': 1, 'Freestyle': 2, 'Kaszek': 2, 'm...
# 1091  {'Accel': 46.00000000000003, 'Redpoint': 62.50...
# 2023  {'G Squared': 9, 'DFJ Growth': 6, 'Founders Fu...
# 3796  {'Hiventures': 2, 'Crowdcube': 1, 'Elad Gil': ...
# 3059  {'Elad Gil': 66.20000000000002, 'SciFi VC': 33...
# 2533  {'Jared Leto': 2, 'Base Ventures': 3, 'Jeff Ke...
# 3473  {'DSC Investment': 9, 'Strong Ventures': 4, 'S...
# 1929  {'Floodgate': 9.1, 'BoxGroup': 15, 'Kevin Lin'...
# 2859  {'David Sacks': 7, 'Y Combinator': 21, 'Lerer ...
# 512   {'Lakestar': 15, 'Trinity Ventures': 322.5, 'Q...

# %% [markdown]
# We can also look at how many investors there are between in any range of scores:

# %%
bottom_score = 0.3
top_score = 0.4
print(f'There are {a.investor_count(bottom_score=0.3,top_score=0.4)} investors with score between {bottom_score} and {top_score}')
# Out:
# There are 388 investors with score between 0.3 and 0.4

# %% [markdown]
# and plot it on a bar chart.

# %%
a.investor_count_chart()

# %% [markdown]
# Looking at the ranking of a sample of well-known investors is a gut-check of our ranking algorithm.

# %%
a.investor_sample()
# Out:
#                        investor_name     score  distance  investments  \
# 255                       Bill Gates  0.378104         1           68
# 5243                  Ridge Ventures  0.341498         1          169
# 3962                     Peter Thiel  0.316442         1           87
# 477                     Y Combinator  0.295502         1         4189
# 6698              Redpoint eventures  0.285649         1           94
# 1921  M12 - Microsoft's Venture Fund  0.280909         1          227
# 922                 WestWave Capital  0.244900         1           62
# 1892       Earlybird Venture Capital  0.197568         1          271
# 383                     500 Startups  0.180419         1         2684
# 1808               Commerce Ventures  0.180066         1          131
# 3068                          Oceans  0.177978         1           22
# 2335                       Techstars  0.148914         1         3525
# 4079                    500 Istanbul  0.080428         2           15
#
#                                               neighbors
# 255   <generator object Runner.run.<locals>.<genexpr...
# 5243  <generator object Runner.run.<locals>.<genexpr...
# 3962  <generator object Runner.run.<locals>.<genexpr...
# 477   <generator object Runner.run.<locals>.<genexpr...
# 6698  <generator object Runner.run.<locals>.<genexpr...
# 1921  <generator object Runner.run.<locals>.<genexpr...
# 922   <generator object Runner.run.<locals>.<genexpr...
# 1892  <generator object Runner.run.<locals>.<genexpr...
# 383   <generator object Runner.run.<locals>.<genexpr...
# 1808  <generator object Runner.run.<locals>.<genexpr...
# 3068  <generator object Runner.run.<locals>.<genexpr...
# 2335  <generator object Runner.run.<locals>.<genexpr...
# 4079  <generator object Runner.run.<locals>.<genexpr...

# %% [markdown]
# If one wants to do a further analysis then they can do so by analyzing the full dataset and the full graph of connections which can be obtained by the following commands.

# %%
df = a.get_data()

# %% [markdown]
# ## Choosing a different experiment file
#
# Note, to choose a different experiment, just change the timestamp manually in the second cell. Alternatively, run the following code to choose the file paths

# %% [markdown]
# ### If you want to choose a different experiment .csv file run the following code

# %%
try:
    from tkinter import Tk
    from tkFileDialog import askopenfilenames
except:
    from tkinter import Tk
    from tkinter import filedialog

Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
filenames = filedialog.askopenfilenames() # show an "Open" dialog box and return the path to the selected file

datadir = filenames[0]

# %% [markdown]
# ### If you want to choose a different params .py file run the following code

# %%
try:
    from tkinter import Tk
    from tkFileDialog import askopenfilenames
except:
    from tkinter import Tk
    from tkinter import filedialog

Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
filenames = filedialog.askopenfilenames() # show an "Open" dialog box and return the path to the selected file

paramdir = filenames[0]

# %%
a = Analyzer(datadir=datadir, paramdir=paramdir)
a.load_data()

# %%
a.get_parameters()
# Out:
# {'before_after_weights': {'before': 1, 'same time': 1, 'after': 1},
#  'decay': 'linear',
#  'max_dist': 3,
#  'n_investments': 30,
#  'cvg_thresh': 0.001}

# %%
a.investor_ranking(top_n=100)
# Out:
#                          investor_name     score  distance  investments  \
# 0                                   GV  1.000000         0          914
# 570                   General Catalyst  1.000000         0          994
# 564                   Felicis Ventures  1.000000         0          527
# 702                 Foundation Capital  1.000000         0          648
# 549                   Battery Ventures  1.000000         0          778
# 729                Andreessen Horowitz  1.000000         0         1110
# 740                First Round Capital  1.000000         0          821
# 528                    Sequoia Capital  1.000000         0         1601
# 830              Union Square Ventures  1.000000         0          363
# 510                    Kleiner Perkins  1.000000         0         1310
# 508                    Khosla Ventures  1.000000         0          973
# 93                            Elad Gil  1.000000         0          116
# 99                            Greylock  1.000000         0          774
# 951          New Enterprise Associates  1.000000         0         1985
# 113                           Redpoint  1.000000         0          684
# 996        Lightspeed Venture Partners  1.000000         0         1053
# 430                     Menlo Ventures  1.000000         0          687
# 1059                               CRV  1.000000         0          594
# 1079                         Floodgate  1.000000         0          340
# 383                      True Ventures  1.000000         0          589
# 357                      Mayfield Fund  1.000000         0          607
# 348                      Intel Capital  1.000000         0         1488
# 341                      Founders Fund  1.000000         0          726
# 1682                              DCVC  1.000000         0          434
# 1872                         Eric Ries  1.000000         0           51
# 228                        Lux Capital  1.000000         0          360
# 2069                       Paul Graham  1.000000         0           31
# 30                               Accel  1.000000         0         1717
# 130                          Benchmark  1.000000         0          635
# 603                   Trinity Ventures  1.000000         0          463
# 656                  Lowercase Capital  1.000000         0          188
# 3924                ASU Venture Devils  0.491086         1          131
# 264                       DAG Ventures  0.471365         1          253
# 2031                       Invest Tech  0.453871         1           32
# 216                        Future Fund  0.428238         1           50
# 611                  Advanced Equities  0.424997         1           45
# 666                  Northgate Capital  0.417413         1          112
# 669                  Pinnacle Ventures  0.417324         1           77
# 347                      Icon Ventures  0.415415         1          185
# 571                   Geodesic Capital  0.408213         1           49
# 801               Wing Venture Capital  0.398289         1          122
# 140                          EquityZen  0.397650         1           37
# 3747                 Four Rivers Group  0.397230         1           48
# 2408                    Clear Ventures  0.395417         1           52
# 2901                 Sherpalo Ventures  0.392363         1           69
# 2599                   Marc Andreessen  0.391645         1           36
# 2216                      WPP Ventures  0.391334         1           66
# 271                       Fuse Capital  0.389125         1           53
# 457                     Tenaya Capital  0.388150         1          186
# 1159                 NextWorld Capital  0.385765         1           46
# 2036                       Jeff Weiner  0.385671         1           41
# 616                  Altimeter Capital  0.385123         1           78
# 374                      Sozo Ventures  0.380482         1           33
# 988        Crosspoint Venture Partners  0.380140         1           87
# 1194            Rustic Canyon Partners  0.380027         1          105
# 3842               Syddansk Innovation  0.379823         1           38
# 45                              Oracle  0.378930         1           41
# 2674                  Amidzad Partners  0.377774         1           43
# 3087               MentorTech Ventures  0.376945         1           43
# 3191              Pilot House Ventures  0.376698         1           54
# 2731                  Juniper Networks  0.376555         1           46
# 1997                       Aaron Levie  0.374714         1           44
# 417                     Focus Ventures  0.372925         1          136
# 92                            ESO Fund  0.371938         1           75
# 2271                     Georges Harik  0.371473         1           43
# 922           Madrone Capital Partners  0.371355         1           37
# 3377           Time Warner Investments  0.369774         1           94
# 800               VentureTech Alliance  0.368171         1           45
# 370                      Shlomo Kramer  0.367927         1           50
# 2334                     Ronald Conway  0.367876         1           98
# 2510                    Wipro Ventures  0.366449         1           32
# 306                       SuRo Capital  0.365813         1           65
# 1156                 Ignition Partners  0.365229         1          312
# 1659                               AOL  0.363612         1           36
# 942          Integral Capital Partners  0.363583         1          100
# 1015     Worldview Technology Partners  0.362744         1          135
# 87                            CapitalG  0.362097         1           99
# 2013                       Chris Sacca  0.361807         1           39
# 3512       Summerhill Venture Partners  0.361685         1           31
# 280                       Keith Rabois  0.361646         1           58
# 2190                      Reid Hoffman  0.360726         1           73
# 943          Inventus Capital Partners  0.359829         1           54
# 3381           Webb Investment Network  0.359747         1          142
# 327                      Base Partners  0.358057         1           37
# 1021    Institutional Venture Partners  0.357828         1          356
# 173                         Bill Gates  0.357446         1           68
# 2074                       S28 Capital  0.356727         1           68
# 1038  SharesPost Investment Management  0.356027         1           79
# 574                   Harmony Partners  0.355721         1           79
# 3011                Rose Tech Ventures  0.355511         1           42
# 1012     Lehman Brothers Holdings Inc.  0.354770         1          107
# 1091                       ComVentures  0.353957         1          129
# 685                  Valhalla Partners  0.353619         1           90
# 2020                       Dylan Field  0.353340         1           47
# 919           Glynn Capital Management  0.353142         1           97
# 1173                WK Technology Fund  0.351726         1           31
# 650                  J.H. Whitney & Co  0.351579         1           44
# 525                    Raymond Tonsing  0.349845         1           52
# 1481                 Kresge Foundation  0.349136         1           38
# 704                 Green Bay Ventures  0.348023         1           41
#
#                                               neighbors
# 0     {'NFX': 6, 'REV': 14, 'Google': 15, 'ZhenFund'...
# 570   {'Accel': 198, 'WndrCo': 7, 'Crowdcube': 22, '...
# 564   {'Sapphire': 33, 'Skip Capital': 25, 'Index Ve...
# 702   {'DHVC': 23, 'ZhenFund': 2, 'GGV Capital': 25,...
# 549   {'ESO Fund': 17, 'PremjiInvest': 6, 'Icon Vent...
# 729   {'Accel': 140, 'Goldman Sachs': 39, 'Index Ven...
# 740   {'GV': 149, 'TPG Biotech': 20, 'Foresite Capit...
# 528   {'Alumni Ventures': 13, 'Tenaya Capital': 140,...
# 830   {'SV Angel': 145, 'Lux Capital': 45, 'George B...
# 510   {'TCV': 35, 'Accel': 134, 'Focus Ventures': 69...
# 508   {'G Squared': 13, 'Bill Gates': 76, 'Alexis Oh...
# 93    {'Group 11': 12, 'Base Partners': 6, 'Zeev Ven...
# 99    {'RUSNANO': 14, 'Gimv': 20, '8VC': 14, 'Coatue...
# 951   {'J.H. Whitney & Co': 57, 'DFJ Growth': 48, 'L...
# 113   {'ESO Fund': 11, 'Greylock': 86, 'In-Q-Tel': 1...
# 996   {'GIC': 37, 'Founders Fund': 88, 'Spark Capita...
# 430   {'TCV': 16, 'Cross Creek': 10, 'Spark Capital'...
# 1059  {'Matrix Partners': 76, 'Tudor Growth Equity':...
# 1079  {'Cherry Tree Investments': 19, 'Shasta Ventur...
# 383   {'REV': 12, 'Intel Capital': 46, 'G Squared': ...
# 357   {'Fuse Capital': 16, 'Accel': 109, 'Sapphire':...
# 348   {'TPG Growth': 18, 'Sprout Group': 24, 'Sapphi...
# 341   {'GIC': 19, 'SV Angel': 202, 'Velocity': 12, '...
# 1682  {'GIC': 10, 'Battery Ventures': 40, 'Instituti...
# 1872  {'DCVC': 6, 'Pear VC': 7, 'HAX': 4, 'SOSV': 4,...
# 228   {'SV Angel': 39, 'George Burke': 2, 'IOSG Vent...
# 2069  {'JAM Fund': 1, 'Xavier Niel': 2, '4DX Venture...
# 30    {'14W': 39, 'H14': 30, 'TCV': 80, 'GIC': 23, '...
# 130   {'Sapphire': 17, 'DAG Ventures': 293, 'Opus Ca...
# 603   {'Lakestar': 18, 'Matrix Partners': 156, 'Sapp...
# 656   {'Accel': 29, 'EquityZen': 1, 'Sands Capital':...
# 3924  {'SFC Capital': 1, 'Jared Leto': 1, 'Dylan Fie...
# 264   {'Sapphire': 10, 'Benchmark': 293, 'Greylock':...
# 2031  {'Wayra': 1, 'Redpoint eventures': 1, 'Igah, V...
# 216   {'Mid-Atlantic Venture Funds': 16, 'Beacon Cap...
# 611   {'Credit Suisse': 2, 'Manhattan Venture Partne...
# 666   {'Tenaya Capital': 25, 'Sequoia Capital': 121,...
# 669   {'RUSNANO': 4, 'Greylock': 47, 'GGV Capital': ...
# 347   {'ESO Fund': 1, 'PremjiInvest': 1, 'RUSNANO': ...
# 571   {'GIC': 13, 'Coatue': 32, 'CapitalG': 15, 'Gai...
# 801   {'Redpoint': 28, 'Altimeter Capital': 16, 'Sut...
# 140   {'Accel': 38, 'Redpoint': 5, 'ESO Fund': 7, 'E...
# 3747  {'Sequoia Capital': 56, 'Webb Investment Netwo...
# 2408  {'Avant Global': 1, 'DN Capital': 9, '25Madiso...
# 2901  {'Baseline Ventures': 3, 'SV Angel': 22, 'E-Me...
# 2599  {'Greylock': 8, 'Floodgate': 2, 'Reid Hoffman'...
# 2216  {'Redpoint': 38, 'Frog Capital': 3, 'ePlanet C...
# 271   {'Mayfield Fund': 16, 'Foundation Capital': 18...
# 457   {'EquityZen': 8, 'Sigma Partners': 24, 'GGV Ca...
# 1159  {'EquityZen': 2, 'Vulcan Capital': 4, 'SharesP...
# 2036  {'Dylan Field': 5, 'Kevin Hartz': 2, 'Lachy Gr...
# 616   {'G Squared': 6, 'T. Rowe Price': 27, 'Sequoia...
# 374   {'Swisscom Ventures': 1, 'In-Q-Tel': 2, '10X C...
# 988   {'Foundation Capital': 23, 'Catamount Ventures...
# 1194  {'AllegisCyber': 12, 'Walden Venture Capital':...
# 3842  {'Accelerace': 3, 'EASME - EU Executive Agency...
# 45    {'Novartis': 1, 'Asset Management Ventures (AM...
# 2674  {'ATA Ventures': 5, 'RUSNANO': 4, 'Greylock': ...
# 3087  {'Accel': 13, 'Rho Ventures': 4, 'ARC Angel Fu...
# 3191  {'Sevin Rosen Funds': 9, 'Matrix Partners': 49...
# 2731  {'AT&T': 1, 'Microsoft': 2, 'NBCUniversal': 1,...
# 1997  {'Jared Leto': 6, 'Eric Wu': 1, 'Elad Gil': 6,...
# 417   {'Benchmark': 41, 'EPIC Ventures': 6, 'TCV': 1...
# 92    {'TPG': 7, 'Coatue': 3, 'Sky UK': 3, 'Greylock...
# 2271  {'EASME - EU Executive Agency for SMEs': 1, 'A...
# 922   {'Jackson Square Ventures': 20, 'Dragoneer Inv...
# 3377  {'GV': 14, '500 Startups': 10, 'Rothenberg Ven...
# 800   {'RUSNANO': 4, 'Greylock': 24, 'Pinnacle Ventu...
# 370   {'Coatue': 18, 'Greylock': 30, 'Acrew Capital'...
# 2334  {'Telstra Ventures': 2, 'Akkadian Ventures': 2...
# 2510  {'ClearSky': 9, 'Khosla Ventures': 17, 'WI Har...
# 306   {'SEEK': 6, 'G Squared': 15, 'Learn Capital': ...
# 1156  {'Innovacom': 15, 'Samsung Electronics': 5, 'A...
# 1659  {'General Catalyst': 14, 'EPIC Ventures': 1, '...
# 942   {'TPG Growth': 5, 'Sprout Group': 11, 'Intel C...
# 1015  {'Crosslink Capital': 26, 'Artis Ventures (AV)...
# 87    {'GIC': 3, 'Coatue': 22, 'Gaingels': 1, 'Black...
# 2013  {'Biz Stone': 1, 'Max Levchin': 4, 'Anthos Cap...
# 3512  {'Temasek Holdings': 9, 'Union Square Ventures...
# 280   {'DAG Ventures': 3, 'Sequoia Capital': 24, 'No...
# 2190  {'SV Angel': 15, 'Pathfinder': 1, 'David Sacks...
# 943   {'Menlo Ventures': 62, 'IA Capital Group': 28,...
# 3381  {'Partech': 2, 'Wavemaker Partners': 4, 'Morad...
# 327   {'Accel': 24, 'Sapphire': 12, 'Elad Gil': 6, '...
# 1021  {'G Squared': 14, 'T. Rowe Price': 54, 'Sequoi...
# 173   {'G Squared': 5, 'Alexis Ohanian': 10, 'Pario ...
# 2074  {'Lakestar': 2, 'Greylock': 16, 'LeFrak': 4, '...
# 1038  {'TPG': 6, 'Coatue': 7, 'ESO Fund': 7, 'G Squa...
# 574   {'83North': 18, 'RTP Ventures': 12, 'Poalim Eq...
# 3011  {'New York Angels': 36, 'Felicis Ventures': 4,...
# 1012  {'Foundation Capital': 9, 'Crosspoint Venture ...
# 1091  {'Accel': 31, 'Redpoint': 40, 'Baker Capital':...
# 685   {'Menlo Ventures': 16, 'HarbourVest Partners':...
# 2020  {'SV Angel': 10, 'Justin Kan': 3, 'Mark Cuban'...
# 919   {'Fidelity': 6, 'Alumni Ventures': 11, 'SoftBa...
# 1173  {'Singtel Innov8': 4, 'TELUS Ventures': 16, 'S...
# 650   {'New Enterprise Associates': 57, 'Frazier Hea...
# 525   {'GV': 16, 'NFX': 3, 'ZhenFund': 1, 'Polychain...
# 1481  {'Compound': 1, 'Felicis Ventures': 5, 'Lux Ca...
# 704   {'GIC': 12, 'Coatue': 25, 'CapitalG': 7, 'Gain...
